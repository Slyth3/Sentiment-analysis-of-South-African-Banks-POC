# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
x= np.arange(1,10)
y= np.arange(1,10)

# %%
fig = plt.figure(figsize=(10,5))

ax = fig.add_axes([0,0,1,1])

                 
ax.plot (x,y, label = "graph1")
ax.plot( 1/y,x*2, label = "graph 1") 

ax.legend()

# %%
fig.add
